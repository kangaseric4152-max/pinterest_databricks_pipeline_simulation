-- %%
-- select post_year, post_quarter, count(*) as rows
-- from workspace.default.pinterest_posts_bronze
-- group by 1,2
-- order by 1,2;

-- select
--   count(*) as total,
--   sum(case when _corrupt_record is not null then 1 else 0 end) as corrupt_rows
-- from workspace.default.pinterest_posts_bronze;
-- select post_year, tag, count(*) cnt
-- from workspace.default.pinterest_post_tags_silver
-- group by 1,2
-- order by cnt desc
-- limit 25;

describe workspace.default.pinterest_post_tags_silver;
SELECT COUNT(*) FROM workspace.default.pinterest_posts_bronze;
SELECT COUNT(*) FROM workspace.default.pinterest_post_tags_silver;
SELECT * FROM workspace.default.pinterest_tag_counts_gold ORDER BY tag_count DESC LIMIT 25;
