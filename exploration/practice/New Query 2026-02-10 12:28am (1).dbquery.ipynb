-- %%
select * from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts limit 10;
select 
  min(date_posted) as min_date, 
  max(date_posted) as max_date, 
  max(likes) as max_likes, 
  avg(likes) as avg_likes 
from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts;
select count(*) as num_rows
from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts;
