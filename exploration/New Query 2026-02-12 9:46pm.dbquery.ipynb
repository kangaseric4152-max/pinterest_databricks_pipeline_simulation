-- %%
SELECT post_year,
       post_quarter,
       SUM(tag_count) AS total_tags
FROM workspace.default.pinterest_tag_counts_gold
GROUP BY 1,2
ORDER BY 1,2;


SELECT
    post_year,
    post_quarter,
    tag,
    tag_count
FROM workspace.default.v_top_tags_by_quarter
WHERE rnk <= 10;

SELECT
    year_q,
    tag,
    tag_count
FROM workspace.default.v_tag_trend;

SELECT
    post_year,
    post_quarter,
    SUM(distinct_users) AS unique_users
FROM workspace.default.pinterest_tag_counts_gold
GROUP BY 1,2
ORDER BY 1,2;
