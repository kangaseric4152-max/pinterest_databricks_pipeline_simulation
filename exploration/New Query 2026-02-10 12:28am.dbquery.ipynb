-- %%
--describe table bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts;
--describe table bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_profiles;
select * from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts limit 5;
select * from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_profiles limit 5;

select 
  count(*) as total,
  count_if(country_code is null) as true_nulls,
  count_if(country_code = 'null') as string_nulls
from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_profiles;
