-- %%
select url, 
       follower_count, 
       cume_dist() over (order by follower_count) as cumulative_distribution
from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_profiles 
order by follower_count desc
limit 25;
