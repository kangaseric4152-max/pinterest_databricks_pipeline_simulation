-- %%
create table pinterest_posts as 
select * from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_posts;
create table pinterest_profiles as 
select * from bright_data_pinterest_profiles_and_posts_datasets.datasets.pinterest_profiles;
