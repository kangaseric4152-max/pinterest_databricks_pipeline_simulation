-- %%
SELECT
  post_year,
  post_quarter,
  tag,
  tag_count,
  distinct_users
FROM workspace.default.v_top_tags_by_quarter
WHERE rnk <= 25
ORDER BY post_year DESC, post_quarter DESC, tag_count DESC, tag;
