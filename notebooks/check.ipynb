# %%
# %sql
select
  count(*) as total_rows,
  sum(case when _corrupt_record is not null then 1 else 0 end) as corrupt_rows,
  sum(case when _rescued_data is not null then 1 else 0 end) as rescued_rows
from workspace.default.pinterest_posts_bronze;

# %%
# %sql
select _source_file, _corrupt_record
from workspace.default.pinterest_posts_bronze
where _corrupt_record is not null
limit 20;
