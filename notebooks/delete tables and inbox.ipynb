# %%
# %sql
DROP TABLE IF EXISTS workspace.default.pinterest_posts_bronze;
DROP TABLE IF EXISTS workspace.default.pinterest_post_tags_silver;

# %%
dbutils.fs.rm("/Volumes/workspace/default/pinterest_pipeline/inbox", recurse=True)
dbutils.fs.rm("/Volumes/workspace/default/pinterest_pipeline/_checkpoints", recurse=True)
dbutils.fs.rm("/Volumes/workspace/default/pinterest_pipeline/_schema", recurse=True)
